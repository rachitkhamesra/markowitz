# 2020-12-31    2395.399902  ...   93.050003  274.950012  1985.300049
#
#             BAJFINANCE.NS  AXISBANK.NS  HDFCBANK.NS  TATAMOTORS.NS  \
# Date
# 2016-01-01     609.585022   449.899994   544.375000     401.899994
# 2016-01-04     605.244995   438.399994   535.250000     377.049988
# 2016-01-05     599.784973   436.450012   531.200012     374.450012
# 2016-01-06     610.724976   430.700012   533.549988     365.899994
# 2016-01-07     610.630005   409.250000   528.099976     343.549988
# ...                   ...          ...          ...            ...
# 2020-12-24    5184.899902   610.200012  1397.099976     175.949997
# 2020-12-28    5204.100098   617.650024  1412.849976     186.350006
# 2020-12-29    5200.500000   630.200012  1427.199951     183.449997
# 2020-12-30    5334.149902   625.099976  1432.500000     184.149994
# 2020-12-31    5295.200195   620.450012  1436.300049     183.850006
#
#             ICICIBANK.NS  POWERGRID.NS  INDUSINDBK.NS
# Date
# 2016-01-01    239.091003    141.000000     963.849976
# 2016-01-04    232.317993    140.949997     934.200012
# 2016-01-05    233.363998    139.149994     935.250000
# 2016-01-06    227.363998    139.500000     943.950012
# 2016-01-07    224.317993    138.100006     925.500000
# ...                  ...           ...            ...
# 2020-12-24    513.549988    190.000000     852.799988
# 2020-12-28    520.099976    191.550003     866.950012
# 2020-12-29    528.799988    189.699997     912.900024
# 2020-12-30    528.750000    190.199997     899.049988
# 2020-12-31    535.049988    189.850006     894.950012
#
# [1232 rows x 48 columns]

# %%
name = list(df)
name
# Out:
# ['ADANIPORTS.NS',
#  'TECHM.NS',
#  'BRITANNIA.NS',
#  'TCS.NS',
#  'SUNPHARMA.NS',
#  'INFY.NS',
#  'HINDALCO.NS',
#  'DRREDDY.NS',
#  'HCLTECH.NS',
#  'HINDUNILVR.NS',
#  'TATASTEEL.NS',
#  'NTPC.NS',
#  'CIPLA.NS',
#  'ITC.NS',
#  'BPCL.NS',
#  'WIPRO.NS',
#  'JSWSTEEL.NS',
#  'GAIL.NS',
#  'DIVISLAB.NS',
#  'ULTRACEMCO.NS',
#  'NESTLEIND.NS',
#  'ASIANPAINT.NS',
#  'EICHERMOT.NS',
#  'IOC.NS',
#  'GRASIM.NS',
#  'BAJAJ-AUTO.NS',
#  'HDFC.NS',
#  'M&M.NS',
#  'UPL.NS',
#  'SHREECEM.NS',
#  'MARUTI.NS',
#  'TITAN.NS',
#  'BAJAJFINSV.NS',
#  'KOTAKBANK.NS',
#  'COALINDIA.NS',
#  'BHARTIARTL.NS',
#  'HEROMOTOCO.NS',
#  'LT.NS',
#  'ONGC.NS',
#  'SBIN.NS',
#  'RELIANCE.NS',
#  'BAJFINANCE.NS',
#  'AXISBANK.NS',
#  'HDFCBANK.NS',
#  'TATAMOTORS.NS',
#  'ICICIBANK.NS',
#  'POWERGRID.NS',
#  'INDUSINDBK.NS']

# %%
def CAGR(df,name):
    
    #USING df[name] and iloc function, identify the initial price of stock 
    start_value = df[name].iloc[0]
    
    #Like we did for Start Value, USING df[name] and iloc function, identify the final price of stock 
    end_value = df[name].iloc[-1]
    
    #Specify the Number of years we are taking into account 
    n = 5
    
    #WRITE THE CAGR FUNCTION USING START VALUE, END VALUE AND NUMBER OF PERIODS
    cagr = (end_value/start_value)**(1/n) -1 
    
    return cagr

# %%
def volatility(df,name):
    df[name] = df[name].pct_change()
    vol = df[name].std(ddof=0) * np.sqrt(252)
    return vol

# %%
def sharpe(x,y,rf):
    
    #Write down the Sharpe Ratio formula using CAGR, Volatility and Risk-Free rate
    sr = (x - 0.06)/y
    
    return sr

# %%
cagr = []
vol = []
sr = []
rf = 0.06
for i in range(len(name)):
    x = CAGR(df, name[i])
    y = volatility(df, name[i])
    z = sharpe(x,y,rf)
    cagr.append(x)
    vol.append(y)
    sr.append(z)

#PRINT CAGR, VOL, SR LIST
print(sr)
# Out:
# [0.18068245477048975, 0.23772640580515617, 0.4918751866486566, 0.49461919141633914, -0.36961621138164813, 0.4157060550580363, 0.4104646748914801, 0.1663676075912103, 0.41434475141306476, 0.7160329573311028, 0.3992257748630759, -0.371862806099429, -0.05004698085182572, -0.249487133783008, -0.02592969421681889, 0.27573429619633294, 0.6740290736724791, -0.07533354796957267, 0.5875533268898606, 0.25488084248231957, 0.7959769550066873, 0.7706575605456922, 0.052755158377256944, -0.2844876958908887, 0.11137706066041986, 0.01775305846248442, 0.30947275175411393, -0.10484788634761683, 0.09974581738352396, 0.33368316667886433, 0.14378562456984884, 0.8446366391063602, 0.7895699676143428, 0.5764548757620351, -0.766725814085621, 0.12349731204063494, -0.0988518651590619, 0.08372993852569964, -0.4679595031845641, -0.056444278375967515, 0.8234749651084392, 1.149947985638071, 0.01663937473646884, 0.651620848687381, -0.42528123168683873, 0.31204936060462796, 0.005358393500279929, -0.15840154869587744]

# %%
df0 = pd.DataFrame()
df0["Name"] = name
df0["Sharpe Ratio"] = sr 
df0["CAGR"] = cagr
df0["Vol"] = vol

df0.sort_values(by = "Sharpe Ratio", ascending = False, inplace = True)
newlist = df0[:15]["Name"].tolist()
df0
# Out:
#              Name  Sharpe Ratio      CAGR       Vol
# 41  BAJFINANCE.NS      1.149948  0.540883  0.418178
# 31       TITAN.NS      0.844637  0.348035  0.341017
# 40    RELIANCE.NS      0.823475  0.313554  0.307908
# 20   NESTLEIND.NS      0.795977  0.260243  0.251569
# 32  BAJAJFINSV.NS      0.789570  0.350331  0.367708
# 21  ASIANPAINT.NS      0.770658  0.257622  0.256433
# 9   HINDUNILVR.NS      0.716033  0.228358  0.235126
# 16    JSWSTEEL.NS      0.674029  0.303986  0.361982
# 43    HDFCBANK.NS      0.651621  0.214142  0.236551
# 18    DIVISLAB.NS      0.587553  0.270079  0.357548
# 33   KOTAKBANK.NS      0.576455  0.223708  0.283992
# 3          TCS.NS      0.494619  0.188308  0.259407
# 2    BRITANNIA.NS      0.491875  0.190870  0.266064
# 5         INFY.NS      0.415706  0.178414  0.284851
# 8      HCLTECH.NS      0.414345  0.174733  0.276903
# 6     HINDALCO.NS      0.410465  0.231571  0.417993
# 10   TATASTEEL.NS      0.399226  0.212869  0.382913
# 29    SHREECEM.NS      0.333683  0.161007  0.302703
# 45   ICICIBANK.NS      0.312049  0.174806  0.367910
# 26        HDFC.NS      0.309473  0.152484  0.298844
# 15       WIPRO.NS      0.275734  0.131051  0.257678
# 19  ULTRACEMCO.NS      0.254881  0.133673  0.289049
# 1        TECHM.NS      0.237726  0.133526  0.309287
# 0   ADANIPORTS.NS      0.180682  0.125753  0.363916
# 7      DRREDDY.NS      0.166368  0.108595  0.292093
# 30      MARUTI.NS      0.143786  0.105229  0.314558
# 35  BHARTIARTL.NS      0.123497  0.102691  0.345687
# 24      GRASIM.NS      0.111377  0.097134  0.333405
# 28         UPL.NS      0.099746  0.096986  0.370799
# 37          LT.NS      0.083730  0.084202  0.289053
# 22   EICHERMOT.NS      0.052755  0.078179  0.344600
# 25  BAJAJ-AUTO.NS      0.017753  0.064640  0.261359
# 42    AXISBANK.NS      0.016639  0.066395  0.384338
# 46   POWERGRID.NS      0.005358  0.061300  0.242672
# 14        BPCL.NS     -0.025930  0.049943  0.387860
# 12       CIPLA.NS     -0.050047  0.045834  0.283051
# 39        SBIN.NS     -0.056444  0.038341  0.383724
# 17        GAIL.NS     -0.075334  0.034564  0.337644
# 36  HEROMOTOCO.NS     -0.098852  0.029744  0.306074
# 27         M&M.NS     -0.104848  0.026367  0.320778
# 47  INDUSINDBK.NS     -0.158402 -0.014724  0.471738
# 13         ITC.NS     -0.249487 -0.008699  0.275362
# 23         IOC.NS     -0.284488 -0.034338  0.331606
# 4    SUNPHARMA.NS     -0.369616 -0.061951  0.329939
# 11        NTPC.NS     -0.371863 -0.037732  0.262818
# 44  TATAMOTORS.NS     -0.425281 -0.144797  0.481557
# 38        ONGC.NS     -0.467960 -0.104596  0.351731
# 34   COALINDIA.NS     -0.766726 -0.165179  0.293689

# %%
df2 = pd.DataFrame()
for i in range(len(newlist)):
    df2[newlist[i]] = df1[newlist[i]]
    
df2.reset_index(inplace=True)
df2 = df2.drop(["Date"], axis=1)
df2
# Out:
#       BAJFINANCE.NS     TITAN.NS  RELIANCE.NS  NESTLEIND.NS  BAJAJFINSV.NS  \
# 0        609.585022   352.049988   507.674988   5785.149902    1983.800049
# 1        605.244995   351.399994   497.649994   5669.799805    1959.500000
# 2        599.784973   347.700012   502.575012   5662.399902    1946.000000
# 3        610.724976   347.850006   516.099976   5719.500000    1938.550049
# 4        610.630005   344.049988   506.625000   5638.950195    1927.050049
# ...             ...          ...          ...           ...            ...
# 1227    5184.899902  1495.900024  1994.150024  18566.300780    8992.549805
# 1228    5204.100098  1543.550049  2003.300049  18597.300780    8995.049805
# 1229    5200.500000  1540.099976  1990.050049  18262.699220    8976.049805
# 1230    5334.149902  1552.599976  1995.500000  18379.199220    8961.700195
# 4     -0.017130 -0.004360     -0.018540 -0.017499   -0.019623

# %%
def get_ret_vol_sr(weights):
    weights = np.array(weights)
    ret = np.sum(df3.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(df3.cov()*252, weights)))
    sr = ret/vol
    return np.array([ret, vol, sr])

def min_vol(weights):
    return get_ret_vol_sr(weights)[1]

def neg_sharpe(weights):
# the number 2 is the sharpe ratio index from the get_ret_vol_sr
    return get_ret_vol_sr(weights)[2] * -1

def check_sum(weights):
    #return 0 if sum of the weights is 1
    return np.sum(weights)-1

# %%
a = 1/15
c = ((0,1),)
b = []
d = ()
for i in range(15):
    b.append(a)
    d = d+c

# %%
from scipy.optimize import minimize

# %%
#using minimize

cons = {'type':'eq', 'fun':check_sum}
result_opt = minimize(neg_sharpe, b, method='SLSQP', bounds=d, constraints=cons)
print(result_opt['fun'])
print(result_opt['x'])
# Out:
# -1.4705897752764763
# [1.58522866e-01 1.08465775e-01 1.23769439e-01 2.02165885e-01
#  3.66643350e-17 7.92634459e-02 1.09345878e-01 0.00000000e+00
#  0.00000000e+00 9.67391325e-02 0.00000000e+00 1.21727580e-01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
funds_opt = 10000000
mon_opt = np.dot(funds_opt, result_opt['x'])

# %%
num_sto_opt = mon_opt/df2.iloc[-1]
num_sto_opt

DF_opt = pd.DataFrame(num_sto_opt)
DF_opt.reset_index(inplace = True)
DF_opt.columns = ['Name', 'Number of Shares']
DF_opt = DF_opt.round(6)
DF_opt
# Out:
#              Name  Number of Shares
# 0   BAJFINANCE.NS        299.370864
# 1        TITAN.NS        692.121194
# 2     RELIANCE.NS        623.429383
# 3    NESTLEIND.NS        109.931319
# 4   BAJAJFINSV.NS          0.000000
# 5   ASIANPAINT.NS        286.718922
# 6   HINDUNILVR.NS        456.482769
# 7     JSWSTEEL.NS          0.000000
# 8     HDFCBANK.NS          0.000000
# 9     DIVISLAB.NS        251.800242
# 10   KOTAKBANK.NS          0.000000
# 11         TCS.NS        425.212051
# 12   BRITANNIA.NS          0.000000
# 13        INFY.NS          0.000000
# 14     HCLTECH.NS          0.000000

# %%
import pandas_datareader.data as pdr
import datetime as dt
from statistics import stdev

# %%
fin = dt.datetime(2021, 6, 30)
ini = dt.datetime(2021, 1, 1)

# %%
newdf = pd.DataFrame()

for i in range(len(newlist)):
    try:
        o = pdr.get_data_yahoo(newlist[i],ini,fin)
        newdf[str(newlist[i])] = o["Close"]
    except:
        print('error')
        print(i)

o = pdr.get_data_yahoo('^NSEI',ini,fin)
newdf['Nifty50'] = o["Close"]

# %%
newdf['Portfolio Value'] = np.zeros((122,1))
#newdf.reset_index(inplace = True)
newdf
# Out:
#             BAJFINANCE.NS     TITAN.NS  RELIANCE.NS  NESTLEIND.NS  \
# Date
# 2021-01-01    5280.149902  1558.599976  1987.500000  18450.699219
# 2021-01-04    5216.200195  1550.900024  1990.849976  18377.949219
# 2021-01-05    5119.000000  1570.949951  1966.099976  18558.250000
# 2021-01-06  1282.099976  978.200012  14146.250000     1.000545e+07
# 2021-01-07  1262.150024  962.549988  14137.349609     9.901944e+06
# ...                 ...         ...           ...              ...
# 2021-06-24  1559.199951  989.700012  15790.450195     1.083536e+07
# 2021-06-25  1574.199951  995.650024  15860.349609     1.075574e+07
# 2021-06-28  1571.800049  985.299988  15814.700195     1.071179e+07
# 2021-06-29  1563.050049  983.599976  15748.450195     1.076254e+07
# 2021-06-30  1580.800049  983.500000  15721.500000     1.077315e+07
#
# [122 rows x 17 columns]

# %%
ret1 = (newdf.iloc[-1, 16]/newdf.iloc[0, 16] - 1)
ret2 = (newdf.iloc[-1, 15]/newdf.iloc[1, 15] - 1)
print(ret1*100, '% : Portfolio Return')
print(ret2*100, '% : Nifty50 Return')
# Out:
# 7.443183031446843 % : Portfolio Return
# 11.24043590110344 % : Nifty50 Return

# %%
#stdev(np.array(newdf['Portfolio Value']))
arr1 = np.array(newdf['Portfolio Value'].pct_change())[1:]
vol1 = arr1.std(ddof=0) * np.sqrt(252)
print('Volatility of Portfolio: ', vol1*100)
arr2 = np.array(newdf['Nifty50'].pct_change())[2:]
vol2 = arr2.std(ddof=0) * np.sqrt(252)
print('Volatility of NIFTY50: ', vol2*100)
# Out:
# Volatility of Portfolio:  15.905837562729133
# Volatility of NIFTY50:  18.209100135161584

# %%
#beta
beta = np.log(newdf/newdf.shift(1))
beta = beta.corr().iloc[16,15]*vol1/vol2
beta
# Out:
# 0.7238145836961682

# %%
#jenson's alpha

alpha = ret1 - (0.06 + beta*(ret2-0.06))
alpha
# Out:
# -0.023499208986967973

# %%
#treynor ratio

treynor = (ret1 - 0.06)/beta
treynor
# Out:
# 0.019938573551215436

# %%
print("SR of Portfolio: ", ret1/vol1)
print("SR of NIFTY50: ", ret2/vol2)
# Out:
# SR of Portfolio:  0.46795291364523006
# SR of NIFTY50:  0.6172977147507841

# %%
cov_df = df3.corr()
cov_df['stock1'] = cov_df.index
cov_df = cov_df.melt(id_vars = 'stock1', var_name = "stock2").reset_index(drop = True)
cov_df
# Out:
#             stock1         stock2     value
# 0    BAJFINANCE.NS  BAJFINANCE.NS  1.000000
# 1         TITAN.NS  BAJFINANCE.NS  0.349956
# 2      RELIANCE.NS  BAJFINANCE.NS  0.337040
# 3     NESTLEIND.NS  BAJFINANCE.NS  0.235594
# 4    BAJAJFINSV.NS  BAJFINANCE.NS  0.752850
# ..             ...            ...       ...
# 220   KOTAKBANK.NS     HCLTECH.NS  0.179591
# 221         TCS.NS     HCLTECH.NS  0.535860
# 222   BRITANNIA.NS     HCLTECH.NS  0.221618
# 223        INFY.NS     HCLTECH.NS  0.540527
# 224     HCLTECH.NS     HCLTECH.NS  1.000000
#
# [225 rows x 3 columns]

# %%
cov_df = cov_df[cov_df['stock1'] < cov_df['stock2']].dropna()
highest_corr = cov_df.sort_values("value",ascending = True)
highest_corr.reset_index(inplace = True)

# %%
highest_corr.tail(60)
# Out:
#      index         stock1         stock2     value
# 45      53    HDFCBANK.NS   NESTLEIND.NS  0.261484
# 46     118        INFY.NS    JSWSTEEL.NS  0.261642
# 47      33   NESTLEIND.NS    RELIANCE.NS  0.266402
# 48     114    DIVISLAB.NS    JSWSTEEL.NS  0.268978
# 49      44     HCLTECH.NS    RELIANCE.NS  0.270565
# 50     203    HDFCBANK.NS        INFY.NS  0.273525
# 51     163        INFY.NS   KOTAKBANK.NS  0.277192
# 52      17    RELIANCE.NS       TITAN.NS  0.282526
# 53     119     HCLTECH.NS    JSWSTEEL.NS  0.283382
# 54     111  HINDUNILVR.NS    JSWSTEEL.NS  0.289014
# 55     117   BRITANNIA.NS    JSWSTEEL.NS  0.294381
# 56      90  BAJFINANCE.NS  HINDUNILVR.NS  0.297499
# 57      18   NESTLEIND.NS       TITAN.NS  0.302154
# 58      36  HINDUNILVR.NS    RELIANCE.NS  0.302683
# 59      21  HINDUNILVR.NS       TITAN.NS  0.303313
# 60      27   BRITANNIA.NS       TITAN.NS  0.313555
# 61      94  BAJAJFINSV.NS  HINDUNILVR.NS  0.313694
# 62      25   KOTAKBANK.NS       TITAN.NS  0.315344
# 63      98    HDFCBANK.NS  HINDUNILVR.NS  0.321359
# 64     156  HINDUNILVR.NS   KOTAKBANK.NS  0.324551
# 65      30  BAJFINANCE.NS    RELIANCE.NS  0.337040
# 66      42   BRITANNIA.NS    RELIANCE.NS  0.338122
# 67      22    JSWSTEEL.NS       TITAN.NS  0.348697
# 68      15  BAJFINANCE.NS       TITAN.NS  0.349956
# 69      20  ASIANPAINT.NS       TITAN.NS  0.350718
# 70      34  BAJAJFINSV.NS    RELIANCE.NS  0.351273
# 71     110  ASIANPAINT.NS    JSWSTEEL.NS  0.353075
# 72     162   BRITANNIA.NS   KOTAKBANK.NS  0.356406
# 73      35  ASIANPAINT.NS    RELIANCE.NS  0.357305
# 74     125  ASIANPAINT.NS    HDFCBANK.NS  0.361049
# 75      40   KOTAKBANK.NS    RELIANCE.NS  0.361166
# 76      19  BAJAJFINSV.NS       TITAN.NS  0.362769
# 77     132   BRITANNIA.NS    HDFCBANK.NS  0.363131
# 78      37    JSWSTEEL.NS    RELIANCE.NS  0.372802
# 79     157    JSWSTEEL.NS   KOTAKBANK.NS  0.373930
# 80       5  ASIANPAINT.NS  BAJFINANCE.NS  0.374329
# 81      23    HDFCBANK.NS       TITAN.NS  0.381378
# 82     155  ASIANPAINT.NS   KOTAKBANK.NS  0.391364
# 83      50  ASIANPAINT.NS   NESTLEIND.NS  0.394905
# 84      65  ASIANPAINT.NS  BAJAJFINSV.NS  0.395485
# 85     180  BAJFINANCE.NS   BRITANNIA.NS  0.395579
# 86      38    HDFCBANK.NS    RELIANCE.NS  0.402466
# 87     185  ASIANPAINT.NS   BRITANNIA.NS  0.404543
# 88      95  ASIANPAINT.NS  HINDUNILVR.NS  0.416985
# 89     184  BAJAJFINSV.NS   BRITANNIA.NS  0.417591
# 90     113    HDFCBANK.NS    JSWSTEEL.NS  0.425805
# 91     105  BAJFINANCE.NS    JSWSTEEL.NS  0.436459
# 92      57   BRITANNIA.NS   NESTLEIND.NS  0.448493
# 93      51  HINDUNILVR.NS   NESTLEIND.NS  0.454005
# 94     109  BAJAJFINSV.NS    JSWSTEEL.NS  0.458459
# 95     154  BAJAJFINSV.NS   KOTAKBANK.NS  0.477142
# 96     102   BRITANNIA.NS  HINDUNILVR.NS  0.481115
# 97     150  BAJFINANCE.NS   KOTAKBANK.NS  0.499173
# 98     124  BAJAJFINSV.NS    HDFCBANK.NS  0.501123
# 99     120  BAJFINANCE.NS    HDFCBANK.NS  0.511402
# 100    179     HCLTECH.NS         TCS.NS  0.535860
# 101    178        INFY.NS         TCS.NS  0.538651
# 102    209     HCLTECH.NS        INFY.NS  0.540527
# 103    158    HDFCBANK.NS   KOTAKBANK.NS  0.640270
# 104      4  BAJAJFINSV.NS  BAJFINANCE.NS  0.752850

# %%
final_corr = 100
stocks = ['0', '0', '0', '0']

for i in range(len(highest_corr)):
    #print(i)
    stocks[0] = highest_corr.iloc[i,1]
    stocks[1] = highest_corr.iloc[i,2]
    corr1 = highest_corr.iloc[i,3] #correlation of 0 and 1
    
    for j in range(len(highest_corr)):
        f1 = 0
        if highest_corr.iloc[j, 1] == stocks[1] and highest_corr.iloc[j, 2] not in stocks:
            stocks[2] = highest_corr.iloc[j,2]
            corr2 = highest_corr.iloc[j,3] #correlation of 1 and 2
            f1 = 1
        elif highest_corr.iloc[j, 2] == stocks[1] and highest_corr.iloc[j, 1] not in stocks:
            stocks[2] = highest_corr.iloc[j,1]
            corr2 = highest_corr.iloc[j,3] #correlation of 1 and 2
            f1 = 1
            
        if f1 == 1:
            for k in range(len(highest_corr)):
                f2 = 0
                corr4 = corr5 = corr6 = 0
                if highest_corr.iloc[k, 1] == stocks[2] and highest_corr.iloc[k, 2] not in stocks:
                    stocks[3] = highest_corr.iloc[k,2]
                    corr3 = highest_corr.iloc[k,3] #correlation of 2 and 3
                    f2=1
                elif highest_corr.iloc[k, 2] == stocks[2] and highest_corr.iloc[k, 1] not in stocks:
                    stocks[3] = highest_corr.iloc[k,1]
                    corr3 = highest_corr.iloc[k,3] #correlation of 2 and 3
                    f2=1
                    
                if f2 == 1:
                    for l in range(len(highest_corr)):
                        if highest_corr.iloc[l, 1] == stocks[0] and highest_corr.iloc[l, 2] == stocks[2]:
                            corr4 = highest_corr.iloc[l,3] #correlation of 0 and 2 
                        elif highest_corr.iloc[l, 1] == stocks[2] and highest_corr.iloc[l, 2] == stocks[0]:
                            corr4 = highest_corr.iloc[l,3]
                            
                        if highest_corr.iloc[l, 1] == stocks[0] and highest_corr.iloc[l, 2] == stocks[3]:
                            corr5 = highest_corr.iloc[l,3] #correlation of 0 and 3
                        elif highest_corr.iloc[l, 1] == stocks[3] and highest_corr.iloc[l, 2] == stocks[0]:
                            corr5 = highest_corr.iloc[l,3]
                            
                        if highest_corr.iloc[l, 1] == stocks[1] and highest_corr.iloc[l, 2] == stocks[3]:
                            corr6 = highest_corr.iloc[l,3] #correlation of 1 and 3
                        elif highest_corr.iloc[l, 1] == stocks[3] and highest_corr.iloc[l, 2] == stocks[1]:
                            corr6 = highest_corr.iloc[l,3]
                        #print("here maybe")
                        if corr4!=0 and corr5!=0 and corr6!=0:
                            #print("here")
                            corr = corr1 + corr2 + corr3 + corr4 + corr5 + corr6
                            #arr.append(corr)
                            if corr<final_corr:
                                print(stocks)
                                print(corr, ": Correlation")
                                final_corr = corr
                    stocks[3] = '0'
            stocks[2] = '0'
# Out:
# ['DIVISLAB.NS', 'TCS.NS', 'ASIANPAINT.NS', 'HCLTECH.NS']
# 1.4805978079771616 : Correlation
# ['DIVISLAB.NS', 'TCS.NS', 'ASIANPAINT.NS', 'INFY.NS']
# 1.459360532624752 : Correlation
# ['DIVISLAB.NS', 'TCS.NS', 'ASIANPAINT.NS', 'TITAN.NS']
# 1.2652052729563785 : Correlation
# ['DIVISLAB.NS', 'TCS.NS', 'BAJAJFINSV.NS', 'NESTLEIND.NS']
# 1.138067911850418 : Correlation
# ['DIVISLAB.NS', 'TCS.NS', 'BAJFINANCE.NS', 'NESTLEIND.NS']
# 1.1330626433096547 : Correlation

# %%
four_stocks = pd.DataFrame(df2[['DIVISLAB.NS', 'TCS.NS', 'BAJFINANCE.NS', 'NESTLEIND.NS']])
four_stocks
# Out:
#       DIVISLAB.NS       TCS.NS  BAJFINANCE.NS  NESTLEIND.NS
# 0     1162.500000  1208.199951     609.585022   5785.149902
# 1     1149.699951  1184.800049     605.244995   5669.799805
# 2     1147.500000  1174.469971     599.784973   5662.399902
# 3     1137.199951  1190.800049     610.724976   5719.500000
# 4     1126.949951  1185.619995     610.630005   5638.950195
# ...           ...          ...            ...           ...
# 1227  3749.600098  2909.350098    5184.899902  18566.300780
# 1228  3766.000000  2929.399902    5204.100098  18597.300780
# 1229  3784.199951  2930.500000    5200.500000  18262.699220
# 1230  3799.699951  2909.300049    5334.149902  18379.199220
# 1231  3841.899902  2862.750000    5295.200195  18390.199220
#
# [1232 rows x 4 columns]

# %%
four_stocks_daily = np.log(four_stocks/four_stocks.shift(1))
four_stocks_daily.head()
# Out:
#    DIVISLAB.NS    TCS.NS  BAJFINANCE.NS  NESTLEIND.NS
# 0          NaN       NaN            NaN           NaN
# 1    -0.011072 -0.019558      -0.007145     -0.020140
# 2    -0.001915 -0.008757      -0.009062     -0.001306
# 3    -0.009017  0.013808       0.018076      0.010034
# 4    -0.009054 -0.004360      -0.000156     -0.014183

# %%
def get_ret_vol_sr_four(weights):
    weights = np.array(weights)
    ret = np.sum(four_stocks_daily.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(four_stocks_daily.cov()*252, weights)))
    sr = ret/vol
    return np.array([ret, vol, sr])

def neg_sharpe_four(weights):
# the number 2 is the sharpe ratio index from the get_ret_vol_sr
    return get_ret_vol_sr_four(weights)[2] * -1

def check_sum_four(weights):
    #return 0 if sum of the weights is 1
    return np.sum(weights)-1

# %%
a = 1/4
c = ((0,1),)
b = []
d = ()
for i in range(4):
    b.append(a)
    d = d+c

# %%
cons = {'type':'eq', 'fun':check_sum_four}
result_opt = minimize(neg_sharpe_four, b, method='SLSQP', bounds=d, constraints=cons)
print(result_opt['fun'])
print(result_opt['x'])
# Out:
# -1.3756667540506484
# [0.14938691 0.20563115 0.26871276 0.37626918]

# %%
funds_opt = 10000000
mon_opt_four = np.dot(funds_opt, result_opt['x'])
#mon_opt_four[3] = 0
mon_opt_four
# Out:
# array([1493869.09147533, 2056311.49013171, 2687127.6055569 ,
#        3762691.81283605])

# %%
num_sto_opt_four = mon_opt_four/four_stocks.iloc[-1]
num_sto_opt_four

DF_opt_four = pd.DataFrame(num_sto_opt_four)
DF_opt_four.reset_index(inplace = True)
DF_opt_four.columns = ['Name', 'Number of Shares']
DF_opt_four = DF_opt_four.round(6)
DF_opt_four
# Out:
#             Name  Number of Shares
# 0    DIVISLAB.NS        388.836026
# 1         TCS.NS        718.299359
# 2  BAJFINANCE.NS        507.464781
# 3   NESTLEIND.NS        204.603102

# %%
newdf_four = pd.DataFrame(newdf[['DIVISLAB.NS', 'TCS.NS', 'BAJFINANCE.NS', 'NESTLEIND.NS', 'Nifty50', 'Portfolio Value']])
newdf_four
# Out:
#             DIVISLAB.NS       TCS.NS  BAJFINANCE.NS  NESTLEIND.NS  \
# Date
# 2021-01-01  3849.050049  2928.250000    5280.149902  18450.699219
# 2021-01-04  3862.250000  3039.449951    5216.200195  18377.949219
# 2021-01-05  3842.100098  3093.000000    5119.000000  18558.250000
# 2021-01-06  3879.850098  3051.500000    5030.299805  18515.250000
# 2021-01-07  3803.050049  3032.800049    5081.000000  18127.300781
# ...                 ...          ...            ...           ...
# 2021-06-24  4250.350098  3373.600098    6043.600098  17619.750000
# 2021-06-25  4248.750000  3380.800049    6075.799805  17506.699219
# 2021-06-28  4314.399902  3336.750000    6037.049805  17506.150391
# 2021-06-29  4356.149902  3340.850098    6052.399902  17599.250000
# 2021-06-30  4408.250000  3345.750000    6015.850098  17633.000000
#
#                  Nifty50  Portfolio Value
# Date
# 2021-01-01           NaN     1.002684e+07
# 2021-01-04  14132.900391     1.005858e+07
# 2021-01-05  14199.500000     1.008793e+07
# 2021-01-06  14146.250000     1.000545e+07
# 2021-01-07  14137.349609     9.901944e+06
# ...                  ...              ...
# 2021-06-24  15790.450195     1.083536e+07
# 2021-06-25  15860.349609     1.075574e+07
# 2021-06-28  15814.700195     1.071179e+07
# 2021-06-29  15748.450195     1.076254e+07
# 2021-06-30  15721.500000     1.077315e+07
#
# [122 rows x 6 columns]

# %%
for i in range(len(newdf_four)):
    newdf_four.iloc[i, 5] = np.dot(np.array(DF_opt_four['Number of Shares']), np.array(newdf_four.iloc[i, :4]).T)
    
newdf_four
# Out:
#             DIVISLAB.NS       TCS.NS  BAJFINANCE.NS  NESTLEIND.NS  \
# Date
# 2021-01-01  3849.050049  2928.250000    5280.149902  18450.699219
# 2021-01-04  3862.250000  3039.449951    5216.200195  18377.949219
# 2021-01-05  3842.100098  3093.000000    5119.000000  18558.250000
# 2021-01-06  3879.850098  3051.500000    5030.299805  18515.250000
# 2021-01-07  3803.050049  3032.800049    5081.000000  18127.300781
# ...                 ...          ...            ...           ...
# 2021-06-24  4250.350098  3373.600098    6043.600098  17619.750000
# 2021-06-25  4248.750000  3380.800049    6075.799805  17506.699219
# 2021-06-28  4314.399902  3336.750000    6037.049805  17506.150391
# 2021-06-29  4356.149902  3340.850098    6052.399902  17599.250000
# 2021-06-30  4408.250000  3345.750000    6015.850098  17633.000000
#
#                  Nifty50  Portfolio Value
# Date
# 2021-01-01           NaN     1.005457e+07
# 2021-01-04  14132.900391     1.009224e+07
# 2021-01-05  14199.500000     1.011043e+07
# 2021-01-06  14146.250000     1.004149e+07
# 2021-01-07  14137.349609     9.944552e+06
# ...                  ...              ...
# 2021-06-24  15790.450195     1.074791e+07
# 2021-06-25  15860.349609     1.074567e+07
# 2021-06-28  15814.700195     1.071978e+07
# 2021-06-29  15748.450195     1.076580e+07
# 2021-06-30  15721.500000     1.077794e+07
#
# [122 rows x 6 columns]

# %%
ret1_four = (newdf_four.iloc[-1, 5]/newdf_four.iloc[0, 5] - 1)
ret2_four = (newdf_four.iloc[-1, 4]/newdf_four.iloc[1, 4] - 1)
print(ret1_four*100, '% : Portfolio Return')
print(ret2_four*100, '% : Nifty50 Return')
# Out:
# 7.194392431865748 % : Portfolio Return
# 11.24043590110344 % : Nifty50 Return

# %%
#stdev(np.array(newdf['Portfolio Value']))
arr1_four = np.array(newdf_four['Portfolio Value'].pct_change())[1:]
vol1_four = arr1_four.std(ddof=0) * np.sqrt(252)
print('Volatility of Portfolio: ', vol1_four*100)
arr2_four = np.array(newdf_four['Nifty50'].pct_change())[2:]
vol2_four = arr2_four.std(ddof=0) * np.sqrt(252)
print('Volatility of NIFTY50: ', vol2_four*100)
# Out:
# Volatility of Portfolio:  16.50698239424774
# Volatility of NIFTY50:  18.209100135161584

# %%
#beta
beta_four = np.log(newdf_four/newdf_four.shift(1))
beta_four = beta_four.corr().iloc[5,4]*vol1_four/vol2_four
beta_four
# Out:
# 0.7077771064626789

# %%
#jenson's alpha

alpha_four = ret1_four - (0.06 + beta_four*(ret2_four-0.06))
alpha_four
# Out:
# -0.025146681268203852

# %%
#treynor ratio

treynor_four = (ret1_four - 0.06)/beta_four
treynor_four
# Out:
# 0.01687526229599415

# %%
print("SR of Portfolio: ", ret1_four/vol1_four)
print("SR of NIFTY50: ", ret2_four/vol2_four)
# Out:
# SR of Portfolio:  0.4358393472554262
# SR of NIFTY50:  0.6172977147507841
